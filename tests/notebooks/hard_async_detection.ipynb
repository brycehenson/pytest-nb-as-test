# %%
import asyncio


async def agen():
    for i in range(3):
        yield i


async for x in agen():
    print(x)

# %%
class A:
    async def __aenter__(self):
        return self

    async def __aexit__(self, *args):
        return False


async with A():
    print("ok")
