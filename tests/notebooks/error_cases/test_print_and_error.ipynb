# %%
print("this is a print statement output with magic key 249873495870")
# Out:
# simple1

# %%
print("second print statement with a different result 834856")

# %%
print("doing nothing")
a = 3 + 3
raise ValueError("error on this line")

# %%
x = 1 + 2
