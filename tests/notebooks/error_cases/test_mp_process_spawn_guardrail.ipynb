# %%
import multiprocessing as mp


def f(x):
    return x + 1


mp.set_start_method("spawn", force=True)
process = mp.Process(target=f, args=(1,))
process.start()
process.join()
assert process.exitcode == 0
