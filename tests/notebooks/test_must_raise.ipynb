# %%
# pytest-nb-as-test: must-raise-exception=True
raise ValueError("intentional error")

# %%
# this second cell should run normally
print("after error")

# %%
import numpy as np

np.array([0, 0]) * 10
